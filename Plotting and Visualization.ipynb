# %% [markdown]
# ##### Brief matplotlob API primer

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = np.arange(10)

# %%
plt.plot(data)

# %% [markdown]
# ## Figures and Subplot

# %% [markdown]
# Plots in matplotlib reside within a `Figure` object.

# %%
fig = plt.figure()

# %% [markdown]
# We can't make a plot with a blank figure.We have to create one or more subplots using `add_subplot`

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax1

# %%
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
fig.show()
# Out:
# c:\users\rockstar\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
plt.plot(np.random.randn(50).cumsum(), 'k--')
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)

# %%
ax2.scatter(np.arange(30), np.arange(30)+3 * np.random.randn(30))

# %%
fig.show()

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2, 2, 1)
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)

ax2 = fig.add_subplot(2, 2, 2)
ax2.scatter(np.arange(30), np.arange(30)+3*np.random.randn(30))

ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %% [markdown]
# `plt.subplots` can create  a new figure and returns a NumPy array containing the created subplot objects.

# %%
fig, axes = plt.subplots(2, 3)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0B7B7D70>,
# ...
#       dtype=object)

# %%
fig, axes = plt.subplots(2, 2)

# %%
fig, axes = plt.subplots(2, 2)

ax1 = fig.add_subplot(2, 2, 1)
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)

# %% [markdown]
# Whatever the subplot we choose, we can give it any data after adding the subplot to the figure.

# %% [markdown]
# ## Adjusting the spacing around the subplots

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)

for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)

plt.subplots_adjust(wspace=0, hspace=0)

# %%
fig, axes = plt.subplots(1, 2, sharex=True, sharey=True)

ax1 = fig.add_subplot(1, 2, 1)
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)

ax2 = fig.add_subplot(1, 2, 2)
plotas = ax2.hist(np.random.randn(100), bins=20, color='g', alpha=0.3)

plt.subplots_adjust(wspace=0.01, hspace=0)

# %% [markdown]
# ### Colors, Markers, and Line Styles

# %%
from numpy.random import randn

# %%
plt.plot(randn(30).cumsum(), 'ko--')

# %% [markdown]
# `ko--`, where ***k*** means black, *--* means dashed type of line, *o* is a marker.

# %% [markdown]
# This could have been written more explicitly as

# %%
plt.plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
data= np.random.randn(30).cumsum()

# %% [markdown]
# By giving a label in the plot:-

# %%
plt.plot(data, 'k--', label='Default')

# %%
plt.plot(data, 'k--', drawstyle='steps-post', label='steps-post')

# %%
plt.plot(data, 'k--', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %% [markdown]
# In `plt.plot` *label* parameter is being shown by the `legend` function. To put the location of label we only need to add `loc` parameter in `legend`function.

# %% [markdown]
# ## Ticks, Labels, and Legends

# %% [markdown]
# The pyplot interface, designed for interactive use, consists of methods like xlim,
# xticks, and xticklabels. These control the plot range, tick locations, and tick labels,
# respectively.
#
# They can be used in two ways:
#
# • Called with no arguments returns the current parameter value (e.g., plt.xlim()
# returns the current x-axis plotting range)
#
#
# • Called with parameters sets the parameter value (e.g., plt.xlim([0, 10]), sets
# the x-axis range to 0 to 10)

# %% [markdown]
# #### Setting the title, axis labels, ticks, and tickables

# %%
fig =plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

# %% [markdown]
# To change the x-axis ticks, t’s easiest to use set_xticks and set_xticklabels. The former instructs matplotlib where to place the ticks along the data range, by default these locations will also be the labels. But we can set any other values as the labels
# using set_xticklabels:

# %%
ticks =ax.set_xticks([0, 250, 500, 750, 1000])

# %%
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                           rotation=30, fontsize='small')

# %%
ax.set_title('Plot')
# Out:
# Text(0.5, 1.0, 'Plot')

# %%
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 3.1999999999999993, 'Stages')

# %%
fig =plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                  rotation=30, fontsize='small')
ax.set_title('Plot')
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 0, 'Stages')

# %%
props = {
    'title': 'My First Plot',
    'xlabel': 'Stages'
}
ax.set(**props)
# Out:
# [Text(0.5, 17.200000000000003, 'Stages'), Text(0.5, 1.0, 'My First Plot')]

# %%
fig =plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                  rotation=30, fontsize='small')
ax.set(**props)
# Out:
# [Text(0.5, 0, 'Stages'), Text(0.5, 1.0, 'My First Plot')]

# %%
fig1 = plt.figure(figsize=(10, 4))
ax = fig1.add_subplot(1, 1, 1)

ax.hist(np.random.randn(1000).cumsum(), bins=50)
ax.set_xticks([0, 100, 200, 300, 400])
ax.set_xticklabels(["one", "two", "three", "four", "five"], rotation=30, fontsize='small')
ax.set_title('Histogram')
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 0, 'Stages')

# %% [markdown]
# ## Adding legends

# %% [markdown]
# We can put a label parameter in `plot` function of `matplotlib`,then by putting `loc` which stands for location of labels in `legend`function we can get a desired labeled figure.

# %%
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')
ax.legend(loc='best')

# %% [markdown]
# ## Annotations and Drawing on a Subplot

# %% [markdown]
# We can add annotations and text using the `text`, `arrow`, and `annotate` functions. `text` draws *text* at given coordinates(x, y) on the plot with optional custom styling.

# %% [markdown]
# ```Python
# >>ax.text(x, y, 'Hello World!', family='monospace', fontsize=10)
# ```

# %% [markdown]
# Annotations can draw both `text` and `arrow` arranged properly.

# %%
import pandas as pd
from datetime import datetime

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax,style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Sterns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
               xytext=(date, spx.asof(date)+225),
               arrowprops=dict(facecolor='black', headwidth=4, width=2,
                              headlength=4),
               horizontalalignment='left', verticalalignment='top')
    
# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])
ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008-2009 financial crisis')

# %% [markdown]
# #### Another example

# %%
fig = plt.figure()

ax = fig.add_subplot(111)
theta = np.arange(0.0, 5.0, 0.01)

cos = np.cos(2*np.pi*theta)

wave = ax.plot(theta, cos, lw=2)

ax.annotate('local max', xy=(2, 1), xytext=(3,1.5),
           arrowprops=dict(facecolor='green', shrink=0.005))
ax.set_ylim([-2, 2])
# Out:
# (-2, 2)

# %% [markdown]
# matplotlib has objects that represent many
# common shapes, referred to as patches. Some of these, like Rectangle and Circle, are
# found in matplotlib.pyplot, but the full set is located in matplotlib.patches

# %% [markdown]
# **To add a shape to a plot, you create the patch object shp and add it to a subplot by
# calling ax.add_patch(shp) **

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                  color='g', alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %% [markdown]
# ## Saving Plots to File

# %% [markdown]
# We can save the ***active*** figure to file using `plt.savefig`

# %%
plt.show()

# %%
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                  color='g', alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)
plt.savefig('figpath_2.png', dpi=400, bbox_inches='tight')

# %%
from io import BytesIO

buffer = BytesIO()
plt.savefig(buffer)
plot_data = buffer.getvalue()

# %% [markdown]
# #### Matplotlib Configuration

# %% [markdown]
# One way to modify the configuration programmatically from python is to use `rc` method.

# %%
plt.rc('figure', figsize=(10, 10))

# %% [markdown]
# An easy way to write down your options in your programs is as a `dict`

# %% [markdown]
# # Plotting with pandas and seaborn

# %% [markdown]
# Pandas itself has built-in methods that simplfy creating visualizations from DataFrame and Series objects.
#
# Another library is `seaborn`, a statistical graphics library.

# %% [markdown]
# #### Line Plots

# %%
import numpy as np

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
s.plot()

# %% [markdown]
# DataFrame's `plot` method plots each of it's columns as a different line on the same subplot, creating legend automatically

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                 columns=['A', 'B', 'C', 'D'],
                 index=np.arange(0, 100, 10))

# %%
df
# Out:
#            A         B         C         D
# 0  -2.453247  0.688002 -1.891160  0.490056
# 10 -2.589702  0.775231 -1.889943 -0.082051
# 20 -2.170668  0.326009 -2.751759  0.511467
# 30 -0.579663  1.348232 -3.003671  1.030479
# 40 -1.985186  1.891589 -2.445347  1.522411
# 50 -2.033594  3.813161 -3.860408  1.429312
# 60 -2.658588  3.158678 -3.637119  0.726994
# 70 -3.596354  3.115515 -4.743610  1.120356
# 80 -4.234631  3.826142 -7.307080  1.862043
# 90 -5.040989  3.045402 -7.763305  1.329152

# %%
df.plot()

# %% [markdown]
# ## Bar plots

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))

data.plot.bar(ax=axes[0], color='g', alpha=0.7)
data.plot.barh(ax=axes[1], color='k', alpha=0.7)

# %%
df = pd.DataFrame([[1, 22, 12, 2], [44, 32, 45, 6], 
                  [122, 343, 5, 6], [1212, 34, 56, 7]],
                 index=['a', 'b', 'c', 'd'],
                 columns=['one', 'two', 'three', 'four'])

# %%
df
# Out:
#     one  two  three  four
# a     1   22     12     2
# b    44   32     45     6
# c   122  343      5     6
# d  1212   34     56     7

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                 index=['one', 'two', 'three', 'four', 'five', 'six'],
                 columns=pd.Index(['A', 'B', 'C', 'D'], names='Genus'))

# %%
df
# Out:
#               A         B         C         D
# one    0.380512  0.646672  0.757879  0.630901
# two    0.660498  0.289089  0.228456  0.525694
# three  0.903084  0.845322  0.929796  0.548152
# four   0.352194  0.642794  0.946646  0.407658
# five   0.504044  0.796891  0.264547  0.805936
# six    0.978308  0.543268  0.236071  0.447865

# %%
df.plot.bar()

# %% [markdown]
# We created stacked bar plots from a DataFrame by passing `stacked=True`,
# resulting in the value in each row being stacked together.

# %%
df.plot.barh(stacked=True, alpha=0.5)

# %% [markdown]
# So now suppose we wanted to make a stacked bar plot showing the percentage of data points for each partysize on each day.

# %%
tips = pd.read_csv('tips.csv')

# %%
party_counts = pd.crosstab(tips['day'], tips['size'])

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts = party_counts.loc[:, 2:5]

# %%
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
party_pacts = party_counts.div(party_counts.sum(1), axis=0)

# %%
party_pacts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_pacts.plot.bar()

# %% [markdown]
# So we can see that party size appear to increase on the weekend in this dataset.

# %% [markdown]
# Data that requires aggregation or summarization before making a plot, using the `seaborn` package can make things much simpler.

# %%
import seaborn as sns

# %%
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.172069

# %%
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')

# %% [markdown]
# So we are getting the most tip percentages on sundays.

# %% [markdown]
# Plotting functions in seaborn takes a `data` argument, which can be pandas DataFrame. The other arguments refer to the column names.

# %% [markdown]
# `seaborn.barplot` has a `hue` option that enables us to split by an additional categorical value.

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h')
sns.set(style="whitegrid")

# %% [markdown]
# ## Histograms and Density Plots
#
# It's kind of a plot bar that gives a discretized display of value frequency. The data points are split into discrete, evenly spaced bins, and the number of data points in is plotted.

# %%
tips['tip_pct'].plot.hist(bins=50)

# %% [markdown]
# Another related plot is known as *density plot*, which is formed by computing an estimate of a continous probablity distribution that might have generated the observed data. This is usual procedure of approximate this distribution as a mixture of "kernels" that is, simple distribution like the normal distribution. Thus density plots are known as **kernal density estimate (KDE)** plots.
#
#
# using `plot.kde` makes a density plot.

# %%
tips['tip_pct'].plot.density()

# %% [markdown]
# We can plot both histogram and continous density estimate simultaneously.

# %%
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(10, 2, size=200)

values = pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(values, bins=100, color='k')

# %% [markdown]
# ## Scatter or Point Plots
#
# Point plots or scatter plots can be useful way of examinig the realtionship between two one-dimensional data series.

# %%
trans_data = pd.DataFrame(np.random.randn(200, 4), 
                         columns=['cpi', 'm1', 'tbilrate', 'unemp'])

# %%
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 195  0.787916  0.606346 -0.738808 -2.441394
# 196 -0.443091 -0.463375  0.645855  1.426562
# 197  0.383828  1.305629  0.751948 -0.750541
# 198  0.478252 -0.910288  0.947990 -0.574943
# 199 -0.472488  0.968830  0.955876 -0.059012

# %% [markdown]
# We can use seaborn's `regplot` method, which makes a scatter plot and firs a linear_regression line

# %%
sns.regplot('m1', 'unemp', data=trans_data)

plt.title('Changes in log %s versus log %s' % ('m1', 'unemp'))
# Out:
# Text(0.5, 1.0, 'Changes in log m1 versus log unemp')

# %% [markdown]
# In EDA we need to be able look at the scatter plots among a group of variables; this is known as a *pair* plot or *scatter plot matrix*.
#
# Seaborn has a convenient `pairplot` function. It supports placing histograms or density estimates of each variable along the digonal.

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha':0.2})

# %%
sns.pairplot(trans_data, diag_kind='hist', plot_kws={'alpha':0.2})

# %% [markdown]
# ## Facet Grids and Categorical Data

# %% [markdown]
# What about datasets where we have additional grouping dimensions? One way to visulize data with many categorical variablesis to use a *facet grid*.
#
# seaborn has useful built in function `catplot` that can make many kinds of faceted plots.

# %%
sns.catplot(x='day', y='tip_pct', hue='time', col='smoker', kind='bar', 
               data=tips[tips.tip_pct < 1])

# %% [markdown]
# Instead of grouping by `time`by differnet bar colors within a facet, we can also expand the facet grid by adding one row per `time` value.

# %%
sns.catplot(x='day', y='tip_pct', row='time', col='smoker',
           kind='bar', data=tips[tips.tip_pct < 1])

# %% [markdown]
# `catplot` aslo supports other plot types like box plots.

# %%
sns.catplot(x='tip_pct', y='day', kind='box', data=tips[tips.tip_pct < 0.5])

# %% [markdown]
# ## The end :) :)
# Not revised.
