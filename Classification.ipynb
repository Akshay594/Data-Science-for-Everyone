# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

iris = pd.read_csv('Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
np.unique(iris.Species)
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris.drop('Id', axis=1, inplace=True)

# %%
X = iris.drop('Species', axis=1)
y = iris['Species']

# %% [markdown]
# # Decision Tree Classifier
#
#
# While making a decision tree our model will ask several questions regarding to the information gain.
# Information gain is used to decide which feature to split on at each step in building the tree.
#
#
#
# ## Gini Impurity
#
# Pure Vs Impure:
#
# Pure: Selected dataset belongs to same class.
#
# Impure: Mixture of different classes.
#
#
# So, Gini impurity is the likelihood of selected class not being from the class labels.

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
clf.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %%
df = iris.copy()

# %%
mapping = {
    "Iris-setosa": 0,
    "Iris-versicolor":1,
    "Iris-virginica":2
}

df["target"] = df["Species"].map(mapping).astype(int)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.drop('Species', axis=1, inplace=True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  target
# 0            5.1           3.5            1.4           0.2       0
# 1            4.9           3.0            1.4           0.2       0
# 2            4.7           3.2            1.3           0.2       0
# 3            4.6           3.1            1.5           0.2       0
# 4            5.0           3.6            1.4           0.2       0

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
clf.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# # Visualization Of Tree

# %%
from sklearn.tree import export_graphviz

export_graphviz(clf, out_file="tree.dot", 
                feature_names=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'],
               class_names=["Setosa","Virginica", "Virsicolor"],
               rounded=True,
               proportion=False,
               precision=2,
               filled=True)

# %%
# !dot -Tpng tree.dot -o tree.png -Gdpi=600

# %%
from IPython.display import Image
Image(filename = 'tree.png')

# %% [markdown]
# # Random Forest

# %%
from IPython.display import Image
Image(filename = 'forest.jpeg')

# %% [markdown]
# Random forest consists of a large number of individual decision trees that operate as an ensemble.
#
#
# `Ensemble means we use multiple learning algos to obtain better predictive performance.`
#
# So, each individual tree spits gives out a class prediction and the class with the most votes becomes our model's prediction.

# %%
from sklearn.ensemble import RandomForestClassifier

rnd_clf = RandomForestClassifier(max_depth=3, n_estimators=10)

# %%
rnd_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=3, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
len(rnd_clf.estimators_)
# rnd_clf.estimators_
# Out:
# 10

# %%
rnd_clf.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# # Hyperparameter Tuning

# %%
RandomForestClassifier().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2,10, 20],
              "max_depth": [None, 2, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20]}

grid = GridSearchCV(estimator=DecisionTreeClassifier(), 
                    param_grid=param_grid, 
                    cv = 5, 
                    scoring='accuracy', 
                    refit=True)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
# ...

# %%
grid.best_score_
# Out:
# 0.9333333333333333

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': None,
#  'max_leaf_nodes': None,
#  'min_samples_leaf': 5,
#  'min_samples_split': 2}

# %%
model = grid.best_estimator_

# %%
model.score(X_test, y_test)
# Out:
# 0.9666666666666667
